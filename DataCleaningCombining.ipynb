# %% [markdown]
# # Dataset Ingestion and Combination
# Key Factors of Interest:
# **Outcome** - House Price per County
#
# Predictors:
# * Income level by county
# * Climate Risk by county
# * Population
# * Type of climate risk by county
# * Population Density or County Size
# * Average School District rating
# * Employment Rate
# * Demographic data by county
# * Democratic vs Republican party affiliation
# * Tax Rate by County
# * Crime Rate
#
# # PROGRESS: Risk, House Price and Average income have been cleaned/merged
# This includes the factors: income level, climate risk, population, county size, house prices.
#
# Remaining datasets:
# * Demographics (Atreya)
# * Crime Rate (J)
# * Tax Rate (S)
# * Political Leaning (J)
# * Employment Rate (S)
# * School Ratings -- if we find data!

# %%
# load libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## 1. Dataset: National Risk Index by County

# %%
risk = pd.read_csv('data/NRI_Table-Counties.csv')
risk.head()
# Out:
#    OID_  NRI_ID   STATE STATEABBRV  STATEFIPS          COUNTY    COUNTYTYPE  \
# 0    68  C02013  Alaska         AK          2  Aleutians East       Borough
# 1    69  C02016  Alaska         AK          2  Aleutians West   Census Area
# 2    70  C02020  Alaska         AK          2       Anchorage  Municipality
# 3    71  C02050  Alaska         AK          2          Bethel   Census Area
# 4    72  C02060  Alaska         AK          2     Bristol Bay       Borough
#
#    COUNTYFIPS  STCOFIPS  POPULATION  ...  WNTW_EALS            WNTW_EALR  \
# 0          13      2013        3374  ...  21.603219       Relatively Low
# 1          16      2016        5168  ...  22.253172       Relatively Low
# 2          20      2020      290985  ...  44.599195       Relatively Low
# 3          50      2050       18633  ...  66.914268  Relatively Moderate
# 4          60      2060         843  ...  11.513463             Very Low
#
#       WNTW_ALRB     WNTW_ALRP  WNTW_ALRA WNTW_ALR_NPCTL     WNTW_RISKV  \
# 0  1.340420e-06  2.981170e-07   0.000000      73.939957   19576.208930
# 1  6.666330e-07  1.967190e-07   0.000000      58.712473   17666.429910
# 2  1.639710e-09  1.107580e-08   0.000002       8.356546   44202.713670
# 3  5.230630e-07  4.266610e-07   0.000000      80.810894  160878.445800
# 4  1.033850e-06  4.301380e-07   0.000000      74.589910    5566.346968
#
#    WNTW_RISKS           WNTW_RISKR  NRI_VER
# 0   23.926185             Very Low   Mar-23
# 1   21.826281             Very Low   Mar-23
# 2   42.729876       Relatively Low   Mar-23
# 3   75.119313  Relatively Moderate   Mar-23
# 4    8.335985             Very Low   Mar-23
#
# [5 rows x 465 columns]

# %% [markdown]
# ### 1.1. Feature Evaluation:
# What is the difference between RISK_VALUE, RISK_SCORE AND RISK_RATNG? Which do we want to focus on?
# ## Decision: Use RISK_SCORE

# %%
# Create order to risk ratings (can later be used instead of categories for ordinal variable)
risk_ord = pd.DataFrame({'RISK_RATNG':['Insufficient Data', 'Very Low', 'Relatively Low', 'Relatively Moderate', 'Relatively High', 
                                       'Very High'], 
                         'risk_level_num':[0,1,2,3,4,5]})
risk_ord.columns
# Out:
# Index(['RISK_RATNG', 'risk_level_num'], dtype='object')

# %%
# Compare Risk Rating to Risk Values
rate_val = risk[['RISK_RATNG', 'RISK_VALUE']].groupby('RISK_RATNG').describe().reset_index()
rate_val.columns = [col_tup[0] + col_tup[1] for col_tup in rate_val.columns]
pd.merge(rate_val, risk_ord, on = 'RISK_RATNG',how="left").sort_values(
    'risk_level_num').set_index('RISK_RATNG').drop(columns = ['risk_level_num'])
# Out:
#                      RISK_VALUEcount  RISK_VALUEmean  RISK_VALUEstd  \
# RISK_RATNG
# Insufficient Data                0.0             NaN            NaN
# Very Low                      1511.0    3.046019e+06   1.520213e+06
# Relatively Low                1091.0    1.162820e+07   4.793438e+06
# Relatively Moderate            397.0    4.698440e+07   2.143723e+07
# Relatively High                129.0    2.230917e+08   1.041345e+08
# Very High                       15.0    1.518860e+09   1.190628e+09
#
#                      RISK_VALUEmin  RISK_VALUE25%  RISK_VALUE50%  \
# RISK_RATNG
# Insufficient Data              NaN            NaN            NaN
# Very Low              3.574127e+04   1.822784e+06   3.038482e+06
# Relatively Low        5.945910e+06   7.593445e+06   1.042852e+07
# Relatively Moderate   2.388258e+07   2.883007e+07   4.039064e+07
# Relatively High       1.084730e+08   1.405654e+08   1.907960e+08
# Very High             6.569027e+08   9.211006e+08   1.246484e+09
#
#                      RISK_VALUE75%  RISK_VALUEmax
# RISK_RATNG
# Insufficient Data              NaN            NaN
# Very Low              4.244946e+06   5.928197e+06
# Relatively Low        1.458174e+07   2.383867e+07
# Relatively Moderate   5.840893e+07   1.053132e+08
# Relatively High       2.835431e+08   5.538074e+08
# Very High             1.446401e+09   5.326193e+09

# %%
# Compare Risk Rating to Risk Scores
rate_score = risk[['RISK_RATNG', 'RISK_SCORE']].groupby('RISK_RATNG').describe().reset_index()
rate_score.columns = [col_tup[0] + col_tup[1] for col_tup in rate_score.columns]
pd.merge(rate_score, risk_ord, on = 'RISK_RATNG',how="left").sort_values(
    'risk_level_num').set_index('RISK_RATNG').drop(columns = ['risk_level_num'])
# Out:
#                      RISK_SCOREcount  RISK_SCOREmean  RISK_SCOREstd  \
# RISK_RATNG
# Insufficient Data                0.0             NaN            NaN
# Very Low                      1511.0       24.053452      13.882674
# Relatively Low                1091.0       65.447025      10.025099
# Relatively Moderate            397.0       89.118676       3.650916
# Relatively High                129.0       97.486478       1.189410
# Very High                       15.0       99.777283       0.142289
#
#                      RISK_SCOREmin  RISK_SCORE25%  RISK_SCORE50%  \
# RISK_RATNG
# Insufficient Data              NaN            NaN            NaN
# Very Low                  0.031817      12.042634      24.053452
# Relatively Low           48.106904      56.776965      65.447025
# Relatively Moderate      82.818963      85.968820      89.118676
# Relatively High          95.450207      96.468342      97.486478
# Very High                99.554566      99.665924      99.777283
#
#                      RISK_SCORE75%  RISK_SCOREmax
# RISK_RATNG
# Insufficient Data              NaN            NaN
# Very Low                 36.064270      48.075088
# Relatively Low           74.117086      82.787146
# Relatively Moderate      92.268533      95.418390
# Relatively High          98.504613      99.522749
# Very High                99.888641     100.000000

# %%
# Key Metrics
main_df = risk[['STATEABBRV', 'COUNTY', 'POPULATION', 'AREA', 'RISK_VALUE', 'RISK_SCORE', 'RISK_RATNG']]
main_df.columns = [col.lower() for col in main_df.columns]
main_df = main_df.rename(columns = {'stateabbrv': 'state'})

# convert county names St. -> Saint
new_county = []
for county in main_df['county'].to_list():
    if county[:3] == 'St.':
        county = 'Saint' + county[3:]
    county = county.replace('ñ', 'n')
    new_county.append(county)
main_df['county'] = new_county

# make county match col which removes all special characters, spaces and lowercases county name
main_df['county_match'] = [re.sub("[^a-zA-Z]", "", county).lower() for county in main_df['county'].to_list()]
    
main_df.head()
# Out:
#   state          county  population          area    risk_value  risk_score  \
# 0    AK  Aleutians East        3374  15167.694230  8.949653e+05    4.231626
# 1    AK  Aleutians West        5168  14258.993100  4.151810e+06   35.221126
# 2    AK       Anchorage      290985   1966.338483  9.456571e+07   94.845689
# 3    AK          Bethel       18633  46015.507070  2.354071e+06   16.926503
# 4    AK     Bristol Bay         843    857.255664  1.055605e+05    0.159084
#
#             risk_ratng   county_match
# 0             Very Low  aleutianseast
# 1             Very Low  aleutianswest
# 2  Relatively Moderate      anchorage
# 3             Very Low         bethel
# 4             Very Low     bristolbay

# %% [markdown]
# ## 2. Dataset: Average House Price by County
# These are average house price for the 3 bedroom homes in that county.

# %%
house_price = pd.read_csv('data/County_house_price.csv')
house_price.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     county        CA    CA
# 1       139         1         Cook County     county        IL    IL
# 2      1090         2       Harris County     county        TX    TX
# 3      2402         3     Maricopa County     county        AZ    AZ
# 4      2841         4    San Diego County     county        CA    CA
#
#                                   Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1    Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2  Houston-The Woodlands-Sugar Land, TX             48                201
# 3             Phoenix-Mesa-Chandler, AZ              4                 13
# 4    San Diego-Chula Vista-Carlsbad, CA              6                 73
#
#       2000-01-31  ...     2024-01-31     2024-02-29     2024-03-31  \
# 0  201912.261325  ...  835213.356408  830842.704551  827397.218457
# 1  138786.730715  ...  299896.888776  301161.714525  303681.845144
# 2   93763.835667  ...  251433.448989  251981.268405  252949.926573
# 3  128670.519165  ...  436641.580342  437524.657383  439110.043819
# 4  203600.293045  ...  856166.371406  860330.459584  867899.083605
#
#       2024-04-30     2024-05-31     2024-06-30     2024-07-31     2024-08-31  \
# 0  828352.309368  831693.814162  834118.549764  837980.932568  843352.706676
# 1  306872.630594  309311.366294  310861.359712  311880.935833  312853.381077
# 2  253822.006471  254347.717766  254240.281757  253935.300370  253584.973440
# 3  440866.652127  442237.549448  442554.952236  442213.244280  441299.790052
# 4  877411.697822  885481.043789  889656.992704  891049.286486  890860.303286
#
#       2024-09-30     2024-10-31
# 0  850013.948373  855185.284307
# 1  313759.921596  314437.668729
# 2  253302.433848  252839.522624
# 3  440419.600392  439637.593015
# 4  890429.118481  889771.059763
#
# [5 rows x 307 columns]

# %%
print(f'The average house price dataset contains {house_price.shape[0]} counties.')
print(f'The risk dataset contains {main_df.shape[0]} rows.')
print('So there will not be complete overlap for all data.')
# Out:
# The average house price dataset contains 2802 counties.
# The risk dataset contains 3231 rows.
# So there will not be complete overlap for all data.

# %%
# Key Factors Subset
price_subset = house_price[['RegionName', 'State', '2023-12-31']]
price_subset.columns = ['county', 'state', 'price']
price_subset
# Out:
#                     county state          price
# 0       Los Angeles County    CA  835952.468135
# 1              Cook County    IL  299433.169006
# 2            Harris County    TX  251136.409812
# 3          Maricopa County    AZ  435967.020147
# 4         San Diego County    CA  854004.938333
# ...                    ...   ...            ...
# 2797      Keya Paha County    NE  229801.607299
# 2798  Golden Valley County    MT  248437.014530
# 2799        Mineral County    CO  444288.990340
# 2800         Hooker County    NE  101293.812292
# 2801       San Juan County    CO  540023.526543
#
# [2802 rows x 3 columns]

# %% [markdown]
# ### 2.1. Combine House Price

# %%
# strip 'County', 'Borough' from RegionName
new_reg_name = []
for county in price_subset['county']:
    if county[-6:] == 'County':
        county = county[:-7]
    elif county[-7:] == 'Borough':
        county = county[:-8]
    elif county[-4:] == 'City':
        county = county[:-5]
    elif county[-6:] == 'Parish':
        county = county[:-7]
    new_reg_name.append(county)
price_subset['county'] = new_reg_name
# Out:
# /var/folders/7n/r66735gn7xx2tdk0357s_k_m0000gn/T/ipykernel_32290/72419673.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_subset['county'] = new_reg_name

# %%
price_subset['county_match'] = [re.sub("[^a-zA-Z]", "", county).lower() for county in price_subset['county'].to_list()]
# Out:
# /var/folders/7n/r66735gn7xx2tdk0357s_k_m0000gn/T/ipykernel_32290/19451233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_subset['county_match'] = [re.sub("[^a-zA-Z]", "", county).lower() for county in price_subset['county'].to_list()]

# %%
merged = pd.merge(main_df, price_subset, on = ['state', 'county_match'], how = 'outer')
merged
# Out:
#      state        county_x  population          area    risk_value  \
# 0       AK  Aleutians East      3374.0  15167.694230  8.949653e+05
# 1       AK  Aleutians West      5168.0  14258.993100  4.151810e+06
# 2       AK       Anchorage    290985.0   1966.338483  9.456571e+07
# 3       AK          Bethel     18633.0  46015.507070  2.354071e+06
# 4       AK     Bristol Bay       843.0    857.255664  1.055605e+05
# ...    ...             ...         ...           ...           ...
# 3240    WY      Sweetwater     42238.0  10597.074000  1.189081e+06
# 3241    WY           Teton     23250.0   4259.833177  1.141156e+07
# 3242    WY           Uinta     20412.0   2109.220457  2.821381e+06
# 3243    WY        Washakie      7662.0   2265.341661  6.211963e+05
# 3244    WY          Weston      6822.0   2424.251552  2.323181e+06
#
#       risk_score           risk_ratng   county_match    county_y         price
# 0       4.231626             Very Low  aleutianseast         NaN           NaN
# 1      35.221126             Very Low  aleutianswest         NaN           NaN
# 2      94.845689  Relatively Moderate      anchorage   Anchorage  3.733779e+05
# 3      16.926503             Very Low         bethel         NaN           NaN
# 4       0.159084             Very Low     bristolbay         NaN           NaN
# ...          ...                  ...            ...         ...           ...
# 3240    6.617881             Very Low     sweetwater  Sweetwater  2.761582e+05
# 3241   68.501432       Relatively Low          teton       Teton  2.334408e+06
# 3242   21.699014             Very Low          uinta       Uinta  2.883248e+05
# 3243    2.513522             Very Low       washakie    Washakie  2.509363e+05
# 3244   16.640153             Very Low         weston      Weston  2.685949e+05
#
# [3245 rows x 10 columns]

# %%
# Counties that exist in House Price df, but not in risk df
merged[merged['risk_ratng'].isnull()]
# Out:
#      state county_x  population  area  risk_value  risk_score risk_ratng  \
# 1501    MO      NaN         NaN   NaN         NaN         NaN        NaN
# 1977    NV      NaN         NaN   NaN         NaN         NaN        NaN
#
#          county_match          county_y          price
# 1501  saintegenevieve  Sainte Genevieve  223287.106181
# 1977           carson            Carson  446056.873731

# %%
# Counties that exist in Risk df, but not in House Price df
merged[merged['price'].isnull()]
# Out:
#      state        county_x  population          area    risk_value  \
# 0       AK  Aleutians East      3374.0  15167.694230  8.949653e+05
# 1       AK  Aleutians West      5168.0  14258.993100  4.151810e+06
# 3       AK          Bethel     18633.0  46015.507070  2.354071e+06
# 4       AK     Bristol Bay       843.0    857.255664  1.055605e+05
# 5       AK         Chugach      7011.0  15296.227860  1.412609e+06
# ...    ...             ...         ...           ...           ...
# 3040    VI      Saint John      3882.0     92.690701           NaN
# 3041    VI    Saint Thomas     41412.0    311.621622           NaN
# 3062    WA        Columbia      3947.0    882.252750  7.855905e+05
# 3067    WA        Garfield      2285.0    725.536389  3.339078e+05
# 3113    WI        Florence      4558.0    502.454196  3.604331e+05
#
#       risk_score         risk_ratng   county_match county_y  price
# 0       4.231626           Very Low  aleutianseast      NaN    NaN
# 1      35.221126           Very Low  aleutianswest      NaN    NaN
# 3      16.926503           Very Low         bethel      NaN    NaN
# 4       0.159084           Very Low     bristolbay      NaN    NaN
# 5       8.017817           Very Low        chugach      NaN    NaN
# ...          ...                ...            ...      ...    ...
# 3040         NaN  Insufficient Data      saintjohn      NaN    NaN
# 3041         NaN  Insufficient Data    saintthomas      NaN    NaN
# 3062    3.595291           Very Low       columbia      NaN    NaN
# 3067    0.827235           Very Low       garfield      NaN    NaN
# 3113    0.986319           Very Low       florence      NaN    NaN
#
# [432 rows x 10 columns]

# %%
# Define new main_df as merged:
main_df = merged

# %% [markdown]
# ## 3. Dataset: Average Income by County

# %%
income = pd.read_excel('data/county_income.xlsx', header = [0,1,2,3])
income.drop([0,3218, 3219, 3220], inplace=True)

# %%
income
# Out:
#      Table 1. Per Capita Personal Income, by County, 2021–2023  \
#                                             Unnamed: 0_level_1
#                                             Unnamed: 0_level_2
#                                             Unnamed: 0_level_3
# 1                                                   NaN
# 2                                               Alabama
# 3                                               Autauga
# 4                                               Baldwin
# 5                                               Barbour
# ...                                                 ...
# 3213                                         Sweetwater
# 3214                                              Teton
# 3215                                              Uinta
# 3216                                           Washakie
# 3217                                             Weston
#
#                                                                     \
#      Per capita personal income1
#                          Dollars                     Rank in state
#                             2021      2022      2023          2023
# 1                            NaN       NaN       NaN           NaN
# 2                        50483.0   51683.0   54209.0            --
# 3                        49174.0   49811.0   53079.0            10
# 4                        56285.0   57621.0   60969.0             4
# 5                        40954.0   41031.0   41531.0            56
# ...                          ...       ...       ...           ...
# 3213                     56150.0   60115.0   64115.0            11
# 3214                    353263.0  418669.0  471751.0             1
# 3215                     44685.0   46401.0   49350.0            23
# 3216                     58601.0   54752.0   57474.0            17
# 3217                     50512.0   51090.0   54380.0            20
#
#
#      Percent change from preceding period
#                            Percent change       Rank in state
#                                      2022  2023          2023
# 1                                     NaN   NaN           NaN
# 2                                     2.4   4.9            --
# 3                                     1.3   6.6             6
# 4                                     2.4   5.8            12
# 5                                     0.2   1.2            58
# ...                                   ...   ...           ...
# 3213                                  7.1   6.7             8
# 3214                                 18.5  12.7             1
# 3215                                  3.8   6.4            11
# 3216                                 -6.6   5.0            17
# 3217                                  1.1   6.4             9
#
# [3217 rows x 8 columns]

# %%
income_subset = income[[('Table 1. Per Capita Personal Income, by County, 2021–2023',
  'Unnamed: 0_level_1',
  'Unnamed: 0_level_2',
  'Unnamed: 0_level_3'),('Table 1. Per Capita Personal Income, by County, 2021–2023',
  'Per capita personal income1',
  'Dollars',
  2023)]]
income_subset.columns = ['county', 'income']
income_subset['state'] = [None]*income_subset.shape[0]
income_subset.drop(income_subset.index[2986:3018], inplace = True)
income_subset
# Out:
# /var/folders/7n/r66735gn7xx2tdk0357s_k_m0000gn/T/ipykernel_32290/2771337655.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_subset['state'] = [None]*income_subset.shape[0]
# /var/folders/7n/r66735gn7xx2tdk0357s_k_m0000gn/T/ipykernel_32290/2771337655.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_subset.drop(income_subset.index[2986:3018], inplace = True)
#           county    income state
# 1            NaN       NaN  None
# 2        Alabama   54209.0  None
# 3        Autauga   53079.0  None
# 4        Baldwin   60969.0  None
# 5        Barbour   41531.0  None
# ...          ...       ...   ...
# 3213  Sweetwater   64115.0  None
# 3214       Teton  471751.0  None
# 3215       Uinta   49350.0  None
# 3216    Washakie   57474.0  None
# 3217      Weston   54380.0  None
#
# [3185 rows x 3 columns]

# %%
null_indexes = list(income_subset[income_subset['county'].isna()].index) + [3218]
for i in range(len(null_indexes)-1):
    start, end = null_indexes[i], null_indexes[i+1]
    income_subset.loc[start+1:end-1, "state"] = income_subset.loc[start+1]['county']

# %%
null_indexes = null_indexes[:-1]
income_subset.drop(null_indexes, inplace = True)
income_subset.drop(np.array(null_indexes) + 1, inplace = True)
# Out:
# /var/folders/7n/r66735gn7xx2tdk0357s_k_m0000gn/T/ipykernel_32290/3799195791.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_subset.drop(null_indexes, inplace = True)
# /var/folders/7n/r66735gn7xx2tdk0357s_k_m0000gn/T/ipykernel_32290/3799195791.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_subset.drop(np.array(null_indexes) + 1, inplace = True)

# %%
states = [
    ('Alabama', 'AL'), ('Alaska', 'AK'), ('Arizona', 'AZ'), ('Arkansas', 'AR'), ('California', 'CA'),
    ('Colorado', 'CO'), ('Connecticut', 'CT'), ('Delaware', 'DE'), ('Florida', 'FL'), ('Georgia', 'GA'),
    ('Hawaii', 'HI'), ('Idaho', 'ID'), ('Illinois', 'IL'), ('Indiana', 'IN'), ('Iowa', 'IA'),
    ('Kansas', 'KS'), ('Kentucky', 'KY'), ('Louisiana', 'LA'), ('Maine', 'ME'), ('Maryland', 'MD'),
    ('Massachusetts', 'MA'), ('Michigan', 'MI'), ('Minnesota', 'MN'), ('Mississippi', 'MS'), ('Missouri', 'MO'),
    ('Montana', 'MT'), ('Nebraska', 'NE'), ('Nevada', 'NV'), ('New Hampshire', 'NH'), ('New Jersey', 'NJ'),
    ('New Mexico', 'NM'), ('New York', 'NY'), ('North Carolina', 'NC'), ('North Dakota', 'ND'), ('Ohio', 'OH'),
    ('Oklahoma', 'OK'), ('Oregon', 'OR'), ('Pennsylvania', 'PA'), ('Rhode Island', 'RI'), ('South Carolina', 'SC'),
    ('South Dakota', 'SD'), ('Tennessee', 'TN'), ('Texas', 'TX'), ('Utah', 'UT'), ('Vermont', 'VT'),
    ('Virginia', 'VA'), ('Washington', 'WA'), ('West Virginia', 'WV'), ('Wisconsin', 'WI'), ('Wyoming', 'WY')
]

state_abbr_df = pd.DataFrame(states, columns=['state', 'abbreviation'])

# %%
inc = pd.merge(income_subset, state_abbr_df, on = 'state', how='left')
inc.drop(columns = 'state', inplace = True)
inc.rename(columns = {'abbreviation': 'state'}, inplace = True)
inc
# Out:
#           county    income state
# 0        Autauga   53079.0    AL
# 1        Baldwin   60969.0    AL
# 2        Barbour   41531.0    AL
# 3           Bibb   39835.0    AL
# 4         Blount   45021.0    AL
# ...          ...       ...   ...
# 3078  Sweetwater   64115.0    WY
# 3079       Teton  471751.0    WY
# 3080       Uinta   49350.0    WY
# 3081    Washakie   57474.0    WY
# 3082      Weston   54380.0    WY
#
# [3083 rows x 3 columns]

# %% [markdown]
# ### 3.1. Merge Income Data

# %%
print(f'Income Data has {inc.shape[0]} counties. So, some counties that may be in price/risk datasets will not be here.')
# Out:
# Income Data has 3083 counties. So, some counties that may be in price/risk datasets will not be here.

# %%
main_df.rename(columns = {'county_x': 'county_risk', 'county_y':'county_price'}, inplace = True)

# %%
# remove endings like "borough" from end of county name
new_county = []
for county in inc['county'].to_list():
    tails = ['City and Borough', 'Borough', 'Census Area', 'Municipality']
    for end in tails:
        if county[-len(end):] == end:
            county = county[:-len(end)-1]
    if county == 'Wise + Norton':
        county = 'Wise'
    if county == 'York + Poquoson':
        county = "York"
    new_county.append(county.replace('St.', 'Saint'))
inc['county'] = new_county

inc['county_match'] = [re.sub("[^a-zA-Z]", "", county).lower() for county in inc['county'].to_list()]
inc.rename(columns = {'county': 'county_inc'}, inplace = True)
inc
# Out:
#       county_inc    income state county_match
# 0        Autauga   53079.0    AL      autauga
# 1        Baldwin   60969.0    AL      baldwin
# 2        Barbour   41531.0    AL      barbour
# 3           Bibb   39835.0    AL         bibb
# 4         Blount   45021.0    AL       blount
# ...          ...       ...   ...          ...
# 3078  Sweetwater   64115.0    WY   sweetwater
# 3079       Teton  471751.0    WY        teton
# 3080       Uinta   49350.0    WY        uinta
# 3081    Washakie   57474.0    WY     washakie
# 3082      Weston   54380.0    WY       weston
#
# [3083 rows x 4 columns]

# %%
merged = pd.merge(main_df, inc, on = ['state','county_match'], how = 'left')
merged
# Out:
#      state     county_risk  population          area    risk_value  \
# 0       AK  Aleutians East      3374.0  15167.694230  8.949653e+05
# 1       AK  Aleutians West      5168.0  14258.993100  4.151810e+06
# 2       AK       Anchorage    290985.0   1966.338483  9.456571e+07
# 3       AK          Bethel     18633.0  46015.507070  2.354071e+06
# 4       AK     Bristol Bay       843.0    857.255664  1.055605e+05
# ...    ...             ...         ...           ...           ...
# 3240    WY      Sweetwater     42238.0  10597.074000  1.189081e+06
# 3241    WY           Teton     23250.0   4259.833177  1.141156e+07
# 3242    WY           Uinta     20412.0   2109.220457  2.821381e+06
# 3243    WY        Washakie      7662.0   2265.341661  6.211963e+05
# 3244    WY          Weston      6822.0   2424.251552  2.323181e+06
#
#       risk_score           risk_ratng   county_match county_price  \
# 0       4.231626             Very Low  aleutianseast          NaN
# 1      35.221126             Very Low  aleutianswest          NaN
# 2      94.845689  Relatively Moderate      anchorage    Anchorage
# 3      16.926503             Very Low         bethel          NaN
# 4       0.159084             Very Low     bristolbay          NaN
# ...          ...                  ...            ...          ...
# 3240    6.617881             Very Low     sweetwater   Sweetwater
# 3241   68.501432       Relatively Low          teton        Teton
# 3242   21.699014             Very Low          uinta        Uinta
# 3243    2.513522             Very Low       washakie     Washakie
# 3244   16.640153             Very Low         weston       Weston
#
#              price      county_inc    income
# 0              NaN  Aleutians East   65421.0
# 1              NaN  Aleutians West   72234.0
# 2     3.733779e+05       Anchorage   79183.0
# 3              NaN          Bethel   48831.0
# 4              NaN     Bristol Bay  169751.0
# ...            ...             ...       ...
# 3240  2.761582e+05      Sweetwater   64115.0
# 3241  2.334408e+06           Teton  471751.0
# 3242  2.883248e+05           Uinta   49350.0
# 3243  2.509363e+05        Washakie   57474.0
# 3244  2.685949e+05          Weston   54380.0
#
# [3245 rows x 12 columns]

# %% [markdown]
# Income data does not have US Territory data - only data within the 50 states. It is also missing granular data in Virginia, but has data regarding combinations of areas, which we may be able to leverage if interested.

# %%
# reset main_df to merged
main_df = merged
main_df
# Out:
#      state     county_risk  population          area    risk_value  \
# 0       AK  Aleutians East      3374.0  15167.694230  8.949653e+05
# 1       AK  Aleutians West      5168.0  14258.993100  4.151810e+06
# 2       AK       Anchorage    290985.0   1966.338483  9.456571e+07
# 3       AK          Bethel     18633.0  46015.507070  2.354071e+06
# 4       AK     Bristol Bay       843.0    857.255664  1.055605e+05
# ...    ...             ...         ...           ...           ...
# 3240    WY      Sweetwater     42238.0  10597.074000  1.189081e+06
# 3241    WY           Teton     23250.0   4259.833177  1.141156e+07
# 3242    WY           Uinta     20412.0   2109.220457  2.821381e+06
# 3243    WY        Washakie      7662.0   2265.341661  6.211963e+05
# 3244    WY          Weston      6822.0   2424.251552  2.323181e+06
#
#       risk_score           risk_ratng   county_match county_price  \
# 0       4.231626             Very Low  aleutianseast          NaN
# 1      35.221126             Very Low  aleutianswest          NaN
# 2      94.845689  Relatively Moderate      anchorage    Anchorage
# 3      16.926503             Very Low         bethel          NaN
# 4       0.159084             Very Low     bristolbay          NaN
# ...          ...                  ...            ...          ...
# 3240    6.617881             Very Low     sweetwater   Sweetwater
# 3241   68.501432       Relatively Low          teton        Teton
# 3242   21.699014             Very Low          uinta        Uinta
# 3243    2.513522             Very Low       washakie     Washakie
# 3244   16.640153             Very Low         weston       Weston
#
#              price      county_inc    income
# 0              NaN  Aleutians East   65421.0
# 1              NaN  Aleutians West   72234.0
# 2     3.733779e+05       Anchorage   79183.0
# 3              NaN          Bethel   48831.0
# 4              NaN     Bristol Bay  169751.0
# ...            ...             ...       ...
# 3240  2.761582e+05      Sweetwater   64115.0
# 3241  2.334408e+06           Teton  471751.0
# 3242  2.883248e+05           Uinta   49350.0
# 3243  2.509363e+05        Washakie   57474.0
# 3244  2.685949e+05          Weston   54380.0
#
# [3245 rows x 12 columns]

# %% [markdown]
# ## 4. Crime Rate

# %%
crime = pd.read_csv('data/crime_report.csv')
crime.drop(crime[crime['report_year'] != 2015].index, inplace = True)
crime
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 2760         2015     NM00101     Albuquerque, NM    559721.0          5406.0
# 2761         2015     TX22001       Arlington, TX    387565.0          1946.0
# 2762         2015     GAAPD00         Atlanta, GA    464710.0          5203.0
# 2763         2015     CO00101          Aurora, CO    360237.0          1660.0
# 2764         2015     TX22701          Austin, TX    938728.0          3497.0
# ...           ...         ...                 ...         ...             ...
# 2824         2015     OK07205           Tulsa, OK    401520.0          3628.0
# 2825         2015     VA12800  Virginia Beach, VA    452797.0           626.0
# 2826         2015     DCMPD00      Washington, DC    672228.0          8084.0
# 2827         2015     KS08703         Wichita, KS    389824.0          3839.0
# 2828         2015         NaN       United States         NaN       1197704.0
#
#       homicides  rapes  assaults  robberies  months_reported  \
# 2760       43.0  404.0    3273.0     1686.0              NaN
# 2761        8.0  208.0    1201.0      529.0              NaN
# 2762       94.0  170.0    2944.0     1995.0              NaN
# 2763       24.0  352.0     837.0      447.0              NaN
# 2764       23.0  487.0    2058.0      929.0              NaN
# ...         ...    ...       ...        ...              ...
# 2824       55.0  365.0    2354.0      854.0              NaN
# 2825       19.0  103.0     234.0      270.0              NaN
# 2826      162.0  494.0    4024.0     3404.0              NaN
# 2827       27.0  349.0    2730.0      733.0              NaN
# 2828    15696.0    NaN       NaN        NaN              NaN
#
#       crimes_percapita  homicides_percapita  rapes_percapita  \
# 2760            965.84                 7.68            72.18
# 2761            502.11                 2.06            53.67
# 2762           1119.62                20.23            36.58
# 2763            460.81                 6.66            97.71
# 2764            372.53                 2.45            51.88
# ...                ...                  ...              ...
# 2824            903.57                13.70            90.90
# 2825            138.25                 4.20            22.75
# 2826           1202.57                24.10            73.49
# 2827            984.80                 6.93            89.53
# 2828            372.60                 4.90              NaN
#
#       assaults_percapita  robberies_percapita
# 2760              584.76               301.22
# 2761              309.88               136.49
# 2762              633.51               429.30
# 2763              232.35               124.08
# 2764              219.23                98.96
# ...                  ...                  ...
# 2824              586.27               212.69
# 2825               51.68                59.63
# 2826              598.61               506.38
# 2827              700.32               188.03
# 2828                 NaN                  NaN
#
# [69 rows x 15 columns]

# %%
crime['total_crimes'] = (crime['crimes_percapita'] + crime['homicides_percapita'] + crime['rapes_percapita'] + 
                         crime['assaults_percapita'] + crime['robberies_percapita'])

# %%
crime[]
